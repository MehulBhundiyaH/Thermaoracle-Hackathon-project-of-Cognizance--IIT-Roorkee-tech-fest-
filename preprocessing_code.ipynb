# %%
statistics = {
    'Column': [],
    'Max': [],
    'Min': [],
    'Mean': [],
    'Std Deviation': []
}


for column in numeric_columns:
    statistics['Column'].append(column)
    statistics['Max'].append(data[column].max())
    statistics['Min'].append(data[column].min())
    statistics['Mean'].append(data[column].mean())
    statistics['Std Deviation'].append(data[column].std())

# Create a DataFrame to display the statistics
statistics_df = pd.DataFrame(statistics)
print(statistics_df)
# Out:
#                             Column          Max        Min         Mean  \
# 0                 Hour 0: Humidity     1.000000   0.000000     0.738260
# 1        Hour 0: Wind Speed (km/h)    57.769565  -4.998558     7.695729
# 2   Hour 0: Wind Bearing (degrees)   367.963070  -2.485756   188.058234
# 3          Hour 0: Visibility (km)    16.100000   0.000000    10.385112
# 4     Hour 0: Pressure (millibars)  1888.288375   0.775925  1079.913885
# 5                 Hour 1: Humidity     1.000000   0.000000     0.738263
# 6        Hour 1: Wind Speed (km/h)    57.769565  -4.998558     7.695817
# 7   Hour 1: Wind Bearing (degrees)   367.963070  -2.485756   188.059213
# 8          Hour 1: Visibility (km)    16.100000   0.000000    10.384967
# 9     Hour 1: Pressure (millibars)  1888.288375   0.775925  1079.914384
# 10                Hour 2: Humidity     1.000000   0.000000     0.738267
# 11       Hour 2: Wind Speed (km/h)    57.769565  -4.998558     7.695847
# ...
